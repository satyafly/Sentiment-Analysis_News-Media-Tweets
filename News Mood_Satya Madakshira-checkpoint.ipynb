# %%
# Dependencies
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import json
import tweepy
import time
import seaborn as sns

# Initialize Sentiment Analyzer
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
analyzer = SentimentIntensityAnalyzer()

# Twitter API Keys
consumer_key = "kwOmXbTbafNHatbaHkA77odIM"
consumer_secret = "h5ane5DCsjqOBBgxRPWPVbxrNidZyJuxQwWuqMqeQzi9PBqheh"
access_token = "28995975-NyXzed89OZWh9QswiAF5luxqAGzQifKiKm22hruL9"
access_token_secret = "eshZZL7AnOg0UpNKwHOd4UDd9PHMRBV0jO33ejTf9tch4"

# Setup Tweepy API Authentication
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tweepy.API(auth, parser=tweepy.parsers.JSONParser())

# %%
target_user = "@BBC"
counter = 1
sentiments = []
for x in range(5):
    
    public_tweets = api.user_timeline(target_user)
     
    for tweet in public_tweets:
        
        compound = analyzer.polarity_scores(tweet["text"])["compound"]
        pos = analyzer.polarity_scores(tweet["text"])["pos"]
        neu = analyzer.polarity_scores(tweet["text"])["neu"]
        neg = analyzer.polarity_scores(tweet["text"])["neg"]
        tweets_ago = counter
                
        sentiments.append({"Date": tweet["created_at"], 
                           "Compound": compound,
                           "Positive": pos,
                           "Negative": neu,
                           "Neutral": neg,
                           "Tweets Ago": counter})
        
        counter = counter + 1
            
BBC_df = pd.DataFrame.from_dict(sentiments)
BBC_df.head()

plt.plot(np.arange(len(sentiments_pd["Compound"])),
         sentiments_pd["Compound"], marker="o", linewidth=0.1,
         alpha=0.8)

plt.title("Sentiment Analysis of Tweets (%s) for %s" % (time.strftime("%x"), target_user))
plt.ylabel("Tweet Polarity")
plt.xlabel("Tweets Ago")
plt.show()

# %%
BBC_df.to_csv('BBC.csv', sep=',')

# %%
target_user = "@CNN"
counter = 1
sentiments = []
for x in range(5):
    public_tweets = api.user_timeline(target_user)

    for tweet in public_tweets:

        compound = analyzer.polarity_scores(tweet["text"])["compound"]
        pos = analyzer.polarity_scores(tweet["text"])["pos"]
        neu = analyzer.polarity_scores(tweet["text"])["neu"]
        neg = analyzer.polarity_scores(tweet["text"])["neg"]
        tweets_ago = counter
        
        sentiments.append({"Date": tweet["created_at"], 
                           "Compound": compound,
                           "Positive": pos,
                           "Negative": neu,
                           "Neutral": neg,
                           "Tweets Ago": counter})
        counter = counter + 1
        

sentiments_pd = pd.DataFrame.from_dict(sentiments)
sentiments_pd.head()


plt.plot(np.arange(len(sentiments_pd["Compound"])),
         sentiments_pd["Compound"], marker="o", linewidth=0.1,
         alpha=0.8)

plt.title("Sentiment Analysis of Tweets (%s) for %s" % (time.strftime("%x"), target_user))
plt.ylabel("Tweet Polarity")
plt.xlabel("Tweets Ago")
plt.show()

# %%
target_user = "@CBS"
counter = 1
sentiments = []
for x in range(5):
    public_tweets = api.user_timeline(target_user)

    for tweet in public_tweets:

        compound = analyzer.polarity_scores(tweet["text"])["compound"]
        pos = analyzer.polarity_scores(tweet["text"])["pos"]
        neu = analyzer.polarity_scores(tweet["text"])["neu"]
        neg = analyzer.polarity_scores(tweet["text"])["neg"]
        tweets_ago = counter
        
        sentiments.append({"Date": tweet["created_at"], 
                           "Compound": compound,
                           "Positive": pos,
                           "Negative": neu,
                           "Neutral": neg,
                           "Tweets Ago": counter})
        counter = counter + 1
        

CBS_df = pd.DataFrame.from_dict(sentiments)
CBS_df.head()


plt.plot(np.arange(len(sentiments_pd["Compound"])),
         sentiments_pd["Compound"], marker="o", linewidth=0.1,
         alpha=0.8)

plt.title("Sentiment Analysis of Tweets (%s) for %s" % (time.strftime("%x"), target_user))
plt.ylabel("Tweet Polarity")
plt.xlabel("Tweets Ago")
plt.show()

# %%
CBS_df.to_csv('CBS.csv', sep=',')

# %%
target_user = "@Fox"
counter = 1
sentiments = []
for x in range(5):
    public_tweets = api.user_timeline(target_user)

    for tweet in public_tweets:

        compound = analyzer.polarity_scores(tweet["text"])["compound"]
        pos = analyzer.polarity_scores(tweet["text"])["pos"]
        neu = analyzer.polarity_scores(tweet["text"])["neu"]
        neg = analyzer.polarity_scores(tweet["text"])["neg"]
        tweets_ago = counter
        
        sentiments.append({"Date": tweet["created_at"], 
                           "Compound": compound,
                           "Positive": pos,
                           "Negative": neu,
                           "Neutral": neg,
                           "Tweets Ago": counter})
        counter = counter + 1
        

Fox_df = pd.DataFrame.from_dict(sentiments)
Fox_df.head()


plt.plot(np.arange(len(sentiments_pd["Compound"])),
         sentiments_pd["Compound"], marker="o", linewidth=0.1,
         alpha=0.8)

plt.title("Sentiment Analysis of Tweets (%s) for %s" % (time.strftime("%x"), target_user))
plt.ylabel("Tweet Polarity")
plt.xlabel("Tweets Ago")
plt.show()

# %%
Fox_df.to_csv('Fox.csv', sep=',')

# %%
target_user = "@NYT"
counter = 1
sentiments = []
for x in range(5):
    public_tweets = api.user_timeline(target_user)

    for tweet in public_tweets:

        compound = analyzer.polarity_scores(tweet["text"])["compound"]
        pos = analyzer.polarity_scores(tweet["text"])["pos"]
        neu = analyzer.polarity_scores(tweet["text"])["neu"]
        neg = analyzer.polarity_scores(tweet["text"])["neg"]
        tweets_ago = counter
        
        sentiments.append({"Date": tweet["created_at"], 
                           "Compound": compound,
                           "Positive": pos,
                           "Negative": neu,
                           "Neutral": neg,
                           "Tweets Ago": counter})
        counter = counter + 1
        

NYT_df = pd.DataFrame.from_dict(sentiments)
NYT_df.head()


plt.plot(np.arange(len(sentiments_pd["Compound"])),
         sentiments_pd["Compound"], marker="o", linewidth=0.5,
         alpha=1)

plt.title("Sentiment Analysis of Tweets (%s) for %s" % (time.strftime("%x"), target_user))
plt.ylabel("Tweet Polarity")
plt.xlabel("Tweets Ago")
plt.show()

# %%
NYT_df.to_csv('NYT.csv', sep=',')

# %%
target_user = "CNN"
counter = 1
sentiments = []
for x in range(5):
    public_tweets = api.user_timeline(target_user)

    for tweet in public_tweets:

        compound = analyzer.polarity_scores(tweet["text"])["compound"]
        pos = analyzer.polarity_scores(tweet["text"])["pos"]
        neu = analyzer.polarity_scores(tweet["text"])["neu"]
        neg = analyzer.polarity_scores(tweet["text"])["neg"]
        tweets_ago = counter
        
        sentiments.append({"Date": tweet["created_at"], 
                           "Compound": compound,
                           "Positive": pos,
                           "Negative": neu,
                           "Neutral": neg,
                           "Tweets Ago": counter})
        counter = counter + 1

# %%
CNN_df.to_csv('CNN.csv', sep=',')

# %%
plt.plot(np.arange(len(sentiments_pd["Compound"])),
         sentiments_pd["Compound"], marker="o", linewidth=0.5,
         alpha=1)

plt.title("Sentiment Analysis of Tweets (%s) for %s" % (time.strftime("%x"), target_user))
plt.ylabel("Tweet Polarity")
plt.xlabel("Tweets Ago")
plt.show()

# %%
News_summary = "Consolidated_data.csv"
News_summary = pd.read_csv(News_summary)

# %%
summary_df = News_summary[['News Channel','Compound', 'Date', 'Negative', 'Neutral', 'Positive', 'Tweets Ago']].copy()
summary_df.head()
# Out:
#   News Channel  Compound                            Date  Negative  Neutral  \
# 0          BBC    0.0000  Mon Jan 08 16:00:05 +0000 2018     1.000    0.000
# 1          BBC    0.0772  Mon Jan 08 15:27:21 +0000 2018     0.925    0.000
# 2          BBC    0.6908  Mon Jan 08 15:00:07 +0000 2018     0.769    0.000
# 3          BBC    0.5106  Mon Jan 08 14:30:06 +0000 2018     0.710    0.000
# 4          BBC    0.3182  Mon Jan 08 14:03:04 +0000 2018     0.728    0.111
#
#    Positive  Tweets Ago
# 0     0.000           1
# 1     0.075           2
# 2     0.231           3
# 3     0.290           4
# 4     0.161           5

# %%
summary_df.plot(kind="scatter", marker="s", x="Tweets Ago", y="Compound", grid=True, figsize=(20,10),
                title="Compound Vs. Lat")

plt.title("Sentiment Analysis of Media Tweets")
plt.xlabel("Tweets Ago")
plt.ylabel("Tweet Polarity")
# Out:
# Text(0,0.5,'Tweet Polarity')

# %%
plt.show()

# %%
summary_df.describe()
# Out:
#          Compound    Negative     Neutral    Positive  Tweets Ago
# count  500.000000  500.000000  500.000000  500.000000  500.000000
# mean     0.109210    0.840240    0.059420    0.100360   50.500000
# std      0.409162    0.169458    0.126719    0.143717   28.894979
# min     -0.784500    0.193000    0.000000    0.000000    1.000000
# 25%      0.000000    0.718250    0.000000    0.000000   25.750000
# 50%      0.000000    0.866500    0.000000    0.000000   50.500000
# 75%      0.406800    1.000000    0.000000    0.163250   75.250000
# max      0.851600    1.000000    0.610000    0.807000  100.000000

# %%
summary_df.groupby(['News Channel']).mean()
# Out:
#               Compound  Negative  Neutral  Positive  Tweets Ago
# News Channel
# BBC            0.21263   0.87080  0.02935   0.09985        50.5
# CBS            0.02932   0.90665  0.03905   0.05430        50.5
# CNN            0.18186   0.87365  0.02460   0.10175        50.5
# Fox            0.15930   0.75155  0.09435   0.15410        50.5
# NYT           -0.03706   0.79855  0.10975   0.09180        50.5

# %%
l = (0.212, 0.029, 0.181, 0.159, -0.037)
x_axis = np.arange(len(l))
plt.bar(x_axis, l, color='r', alpha=0.5, align="edge")
tick_locations = [value+0.4 for value in x_axis]
plt.xticks(tick_locations, ["BBC", "CBS", "CNN", "Fox", "NYT"])
# Out:
# ([<matplotlib.axis.XTick at 0x18996128>,
# ...
#  <a list of 5 Text xticklabel objects>)

# %%
plt.title("Overall Media Sentiment on Twitter")
plt.ylabel('Tweet Polarity')
# Out:
# Text(0,0.5,'Tweet Polarity')

# %%
plt.show()
